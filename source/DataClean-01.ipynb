# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('../data/beijing_apm.csv')
df2 = pd.read_csv('../data/wangfu_zhonghuan.csv')
df3 = pd.read_csv('../data/wangfujing_baihuo.csv')
df4 = pd.read_csv('../data/dongfang_xintiandi.csv')

# %%
df1.insert(df1.shape[1], 'from', '北京apm')
df2.insert(df2.shape[1], 'from', '王府中環')
df3.insert(df3.shape[1], 'from', '王府井百货')
df4.insert(df4.shape[1], 'from', '东方新天地')

# %% [markdown]
# ### Concat and Merge the Data

# %%
dfs = [df1,df2,df3,df4]
new_df = pd.concat(dfs, axis=0, ignore_index=True)

# %%
new_df.drop(labels='review-truncated-words', axis=1, inplace=True)

# %%
new_df.columns = [
    "user_name",
    "facs_score",
    "envr_score",
    "serv_score",
    "review",
    "time",
    "from"
]

# %%
new_df
# Out:
#       user_name facs_score envr_score serv_score  \
# 0           牙大酥     设施：5.0     环境：5.0     服务：5.0
# 1          磕磕绊绊     设施：5.0     环境：5.0     服务：5.0
# 2          吃货阿浪     设施：5.0     环境：5.0     服务：5.0
# 3           祁清和     设施：4.5     环境：4.5     服务：4.5
# 4           樱桃子     设施：4.5     环境：4.5     服务：4.5
# ...         ...        ...        ...        ...
# 14935       NAN     设施：5.0     环境：5.0     服务：5.0
# 14936  tttaxhzj     设施：5.0     环境：5.0     服务：5.0
# 14937   云轩飘语_清凉     设施：4.0     环境：4.0     服务：4.0
# 14938     HHHui     设施：5.0     环境：5.0     服务：5.0
# 14939   Rong耀Z心     设施：5.0     环境：5.0     服务：5.0
#
#                                                   review              time  \
# 0      特别赞的一家商场，在王府井这个商场云集和大牌云集的地方，apm商场算是人气特别高的了。\n交...  2023-04-17 23:12
# 1      LINLEE在王府井apm也开新店了，超级喜欢他们家的口味，和朋友逛街无意看到的，果断去买一...  2023-04-17 21:22
# 2      北京apm \n东城区商场热门榜第一名☝️🥇\n王府井大街138号\n环境：商场环境干净整齐...  2023-04-17 21:05
# 3      一定要错过下午5点半以后，不然吃饭只能排队等半个小时，而且拿到号了一定别因为还有十几桌就走开...  2023-04-17 10:19
# 4      花·Young 的年华……\n2023年3🈷️31日～～5月3日，北京apm首层中庭，迎来7...  2023-04-16 21:47
# ...                                                  ...               ...
# 14935  非常非常非常大的商场\n坐标王府井～\n地铁站出来就是～\n里面品牌还是挺齐全的～\n也有吃...  2019-04-17 07:32
# 14936                               格局比较宽敞，品牌比较全，停车可以用积分  2019-04-17 05:08
# 14937                  当年可是热闹的地方，现在虽然外面看着没什么差别，但人气已经分流了。  2019-04-16 21:42
# 14938  东方新天地在王府井商业街的一边的起始点，人流量大，特别是观光旅游的朋友较多，地铁一号线站王府...  2019-04-16 17:02
# 14939  地标性建筑，现在也是一年不如一年了，当年多少大公司的在楼上办公啊！现在走的差不多了吧！楼下的...  2019-04-15 16:49
#
#         from
# 0      北京apm
# 1      北京apm
# 2      北京apm
# 3      北京apm
# 4      北京apm
# ...      ...
# 14935  东方新天地
# 14936  东方新天地
# 14937  东方新天地
# 14938  东方新天地
# 14939  东方新天地
#
# [14940 rows x 7 columns]

# %% [markdown]
# ## Check for NaN Values

# %%
new_df.isnull().any()
# Out:
# user_name     False
# facs_score    False
# envr_score    False
# serv_score    False
# review        False
# time          False
# from          False
# dtype: bool

# %%
new_df.isnull().sum()
# Out:
# user_name     0
# facs_score    0
# envr_score    0
# serv_score    0
# review        0
# time          0
# from          0
# dtype: int64

# %% [markdown]
# ## Save the new cleaned data

# %%
new_df.to_csv('../data/stores.csv', encoding='utf-8', index=False)
